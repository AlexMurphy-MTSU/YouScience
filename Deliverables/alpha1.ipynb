# %%
""" 
NOTE: COMPLETED - Under revision to incorporate Pathway roster export, Added in Homeroom teacher feature
to cleaned_df and exported Pathway rosters
NOTE: possibly neediing fixed: Pathway Rosters are now AZ by teacher first, so there is not a simple AZ
list of students per block
"""

import pandas as pd
import numpy as np
import random
import os

# implementing random seed for control
sd = 42
np.random.seed(sd)

# %%
# school names for consistency 
schools = ['Oakland Middle School',
    'Siegel Middle School',
    'Whitworth-Buchanan Middle School',
    'Christiana Middle School',
    'Smyrna Middle School',
    'Stewarts Creek Middle School',
    'Rockvale Middle School',
    'Rocky Fork Middle School',
    'Blackman Middle School',
    'Thurman Francis Arts Academy',
    'Rock Springs Middle School',
    'LaVergne Middle School'
]

# capacity report compiled info for all schools at once, see capacity_report.py

# preparing directories
for school in schools:
    path = f'../YouScienceData/Schedules/{school}'
    pathway_path = f'../YouScienceData/Schedules/{school}/Pathway_Rosters'
    if not os.path.exists(path):
        os.makedirs(path)
    if not os.path.exists(pathway_path):
        os.makedirs(pathway_path)

# %% [markdown]
# # Functions
# Note that file_paths will need to be updated for change over to .py scripts
#
# <ul>
#     <li><strong>get_POS_from_clusters</strong> (<i>school</i>), Returns df with translated POS or 0's for missing, feeds from YS_Criteria_by_School prepared sets</li></br>
#     <li><strong>get_POS_demand</strong> (<i>school_pos_df</i>), Needs converted POS df, Returns Counter dictionary object with POS demand count, prints <u># lg rooms and if more are needed based on demand</u></li></br>
#     <li><strong>uncouple_pos_matches</strong> (<i>pos_demand_counter_object</i>), returns a desc list of POS by demand, splits grouped POSs into separate POS each with the same demand, is called by fnc initialize_block_rosters</li></br>
#     <li><strong>initialize_block_rosters</strong> (<i>school</i>), returns pos_rosters empty dictionary structured for building block rosters, returns capacity vector which is used for determining sizes of pos rosters, calls fnc uncouple_pos_rosters</li></br>
#     <li><strong>roster_status</strong> <i>block='B1'</i>, shows current block status, initially was designed to check for fill, is called by fnc backfill_POS(), prints <u>#'s in each POS per specified block</u></li></br>
#     <li><strong>backfill_POS</strong> (<i>block='B1'</i>), returns length of unassigned for block (0 implies block is completely backfilled), uses global "<strong>unassigned</strong>", calls roster_status at end to show results</li></br>
#     <li><strong>fill_pos_block</strong> (<i>block='B1'</i>), returns remaining roster of unmatched students and open seat vector of POS that still have empty seats, assumes global <strong>B1_roster, B2_roster, B3_roster, B4_roster</strong> are initialized with list of students, per block it fills POS's in order of demand by finding students with matches for that POS as First match, then Second and so on until the POS is filled by capacity or all students with matches have been sorted, prints <u>Current match level being examined and current capacity of POS, flags when POS is empty after demanded matches are checked or when POS is filled</u></li></br>
#     <li><strong>check_for_missed</strong> (<i>ranked_df, current_block</i>), is called within fnc fill_POS_block(), returns ranked_df during matching process to prioritize students who were unmatched after previous block's sorting</li></br>
#     <li><strong>append_schedule</strong> (<i>-none-</i>), assumed global <strong>school_pos_df, pos_rosters</strong>, appends 4 columns "B1,...,B4" to translated school_POS_df by using the pos_rosters after a school's sorting is complete</li></br>
#     <li><strong>clean_to_export</strong> (<i>school_pos_df</i>), assumed global <strong>school_pos_df</strong>, tidies larger school_pos_df to specfic features to send to board. Created in case additional transformations are needed during development.</li></br>
#     <li><strong>last_name</strong> (<i>name</i>), used to extract last name from school_pos_df in order to alphabetize cleaned_df to be teacher-friendly</li>
#     <li><strong>export_POS_rosters</strong> (<i>pos_keys, cleaned_df</i>), default pos_keys assumes pos_rosters dict object, default cleaned_df assumes cleaned_df df object, creates a .xlsx file per pathway for a school that contains four blocks' rosters in near-perfect az order and index set to begin with 1 for ease of teacher access.</li>
# </ul>

# %%
def get_POS_from_clusters(school):
    # read in YouScience Matching Df
    ys_path = f'YS_Criteria_by_School/{school} YSCriteria.csv'
    ys_match_df = pd.read_csv(ys_path)
    # Read in appropriate columns form direct_join_prepared.xlsx
    dj_path = f'../direct_join_prepared.xlsx'
    djp = pd.read_excel(dj_path)
    djp = djp[['YouScience Clusters',school]]

    # create replacement dictionary
    to_replace = {}
    for i in range(len(djp)):
        cluster = djp.iloc[i]
        # key = YS cluster from 'YouScience Clusters' column, value = school's coresponding POS from {school} column
        if type(cluster[school]) != float:
            to_replace[cluster['YouScience Clusters']] = cluster[school]
        else:
            to_replace[cluster['YouScience Clusters']] = 0
    
    # at some point '0' is introduced somewhere. I suspect from the added positions in updated rosters
    to_replace['0'] = 0

    return ys_match_df.replace(to_replace=to_replace).drop('Unnamed: 0', axis=1)

def get_POS_demand(school_pos_df):

    from collections import Counter
    C = Counter()
    for i in range(len(school_pos_df)):
        # read in student's POS
        student = school_pos_df.iloc[i]
        # compile list of POS
        pos_list = []
        for rank in ['First','Second','Third','Fourth','Fifth','Sixth']:
            if student[rank] not in pos_list:
                pos_list.append(student[rank])
        # update counter
        C.update(pos_list)
    
    # Updated 11/01 to read from capacity_report.csv
    cap_df = pd.read_csv('../YouScienceData/Reports/Capacity_Report.csv')
    # checking for problems, assumes cap_df exists
    lg_rooms = cap_df.loc[cap_df.School == school]['Number of Large Rooms'].values[0]
    sm_rooms = cap_df.loc[cap_df.School == school]['Number of Small Rooms'].values[0]
    print(f'{school} registered {lg_rooms} large classroom(s) available.')
    need_lg = 0
    for i in C.most_common():
        if i[0] == 0:
            continue
        if lg_rooms > 0:
            check = i[1] <= 200
            lg_rooms -= 1
        else:
            check = i[1] <= 140
        
        if check == False:
            need_lg += 1
    print(f'{school} needs {need_lg} additional large rooms to meet POS demand.')
        
    return C

def uncouple_pos_matches(demand_counter_object):
# NE meanning Non-Empty matches, only
    NE_pos_list = [] 
    for pos in demand_counter_object:
        # the 0 comes from missing / empty matches
        if pos[0] == 0:
            continue
        
        # Break up the Coupled POS matches into separate, equally-demanded POS matches
        if ',' in pos[0]:
            # temp list of elements
            l = pos[0].split(', ')
            for match in l:
                NE_pos_list.append([match, pos[1]])
        # If not coupled, pass in as a list rather than tuple for decrement process later? 
        else:
            NE_pos_list.append(list(pos))

    return NE_pos_list

def initialize_block_rosters(school):
    # initialize dictionary for POS rosters per school
    pos_rosters = {}
    
    for pos_couplet in uncouple_pos_matches(school_demand[school]):
        # pos_key will be a doubleton set [pos_key, demand value]
        pos_rosters[pos_couplet[0]] = {
            'All':[],
            'B1':[],
            'B2':[],
            'B3':[],
            'B4':[],
        }

    # preparing capacity vector
    cap_df = pd.read_csv('../YouScienceData/Reports/Capacity_Report.csv')
    num_lg_rooms = cap_df.loc[cap_df.School == school]['Number of Large Rooms'].values[0] 
    lg_vector, sm_vector = [50] * num_lg_rooms, [35] * (len(pos_rosters) - num_lg_rooms)
    capacity_vector = lg_vector + sm_vector

    return pos_rosters, capacity_vector

def roster_status(block='B1'):
    print(f'{block} Status')
    logf.write(f'{block}_Status\n')
    x = 0
    for key in list(pos_rosters.keys()):
        x += len(pos_rosters[key][block])
        print(key, len(pos_rosters[key][block]))
        logf.write(f'{block}_Status: {key}, {len(pos_rosters[key][block])}\n')
    print(f'{x}/{len(school_pos_df)}\n')  
    logf.write(f'{block}_Status: {x}/{len(school_pos_df)}\n')
    return

def backfill_POS(block='B1'):
    # initialize randomized remaining list
    r_unassigned = random.sample(unassigned, len(unassigned))

    while len(r_unassigned) > 0:
        # get index of most empty POS
        ind = OS_vector.index(max(OS_vector))
        pos_key = list(pos_rosters.keys())[ind]
        # adding student to POS roster
        pos_rosters[pos_key]['All'].append(r_unassigned[0])
        pos_rosters[pos_key][block].append(r_unassigned[0])
        # noting student added to that POS
        OS_vector[ind] -= 1
        # removing student from unassigned list
        r_unassigned.pop(0)

    # tracking progress
    roster_status(block=block)
    return len(r_unassigned)

def fill_pos_block(block='B1'):
    # initialize reference block roster
    remaining_roster = eval(f'{block}_roster')
    pos_list = list(pos_rosters.keys())
    # creating open_seats_vector
    open_seats_vector = []
    # iterating over POS's in block until all students assigned pos during block
    for pos_key in pos_list:
        # initialize choice to filter by
        rankings = ['First', 'Second', 'Third', 'Fourth', 'Fifth', 'Sixth']
        r = 0
        rank = rankings[r]

        # initialize randomized slice of pos_df and index counter, check for priority students
        ranked = school_pos_df.loc[school_pos_df[rank] != 0].sample(frac=1).reset_index(drop=True)
        ranked = check_for_missed(ranked_df=ranked,current_block=block)
        i = 0

        # initialize size of course
        n = 0
        cap = capacity_vector[pos_list.index(pos_key)]

        # filling
        while n < cap:
            try:
                student, choice = ranked.iloc[i].id, ranked.iloc[i][rank]
            except IndexError:
                #print(f'{school}, {n} of {cap} students assigned to {pos_key}, {rank} choice demand met')
                logf.write(f'fill_status: {school}, {n} of {cap} students assigned to {pos_key}, {rank} choice demand met\n')
                # move to next choice ranking
                r += 1
                # check if all rankings have been examined
                if r > 5:
                    #print(f'{school}, {n} students assigned to {pos_key}, All choices examined.')
                    logf.write(f'fill_status: {school}, {n} students assigned to {pos_key}, All choices examined.\n')
                    # check for remaining seats 
                    open_seats = cap - n
                    break
                # else update the df slice for consideration
                rank = rankings[r]
                ranked = school_pos_df.loc[school_pos_df[rank] != 0].sample(frac=1).reset_index(drop=True)
                ranked = check_for_missed(ranked_df=ranked,current_block=block)
                # reset index counter
                i = 0
                continue
            # NOTE: criteria for assigning student to pos: 
            #   ->(i) matched, 
            #   ->(ii) isn't already matched for current block, 
            #   ->(iii) isn't already matched for this pos prior
            if (pos_key in choice) and (student in remaining_roster) and (student not in pos_rosters[pos_key]['All']):
                # assign to master
                pos_rosters[pos_key]['All'].append(student)
                # assign to block specific
                pos_rosters[pos_key][block].append(student)
                n += 1
                remaining_roster.remove(student)
            i += 1
            if n == cap:
                #print(f'{school}, {pos_key} {block} filled.')
                logf.write(f'fill_status: {school}, {pos_key} {block} filled.\n')
                # hence no remaining open seats in POS
                open_seats = 0
        open_seats_vector.append(open_seats)
    # checkign status
    roster_status(block=block)

    return remaining_roster, open_seats_vector

def check_for_missed(ranked_df, current_block):
    # looking at previous block
    prev_block = {
        'B2':'B1',
        'B3':'B2',
        'B4':'B3',
    }
    # will be unneccessary for first block assignments
    if current_block == 'B1':
        return ranked_df
    else:
        block = prev_block[current_block]

    # current list of students with POS match   
    student_ids = list(ranked_df.id)

    # initializing lcoations of priority students with POS match
    target_indices = []

    # checking for priority students
    for id in missed_took_YS[school][block]:
        if id in student_ids:
            ind = ranked_df.loc[ranked_df.id == id].index.values[0]
            target_indices.append(ind)
    
    # preparing new_index to reindex ranked_df before continuing
    new_index = [x for x in target_indices]
    # adding back existing student_ids
    new_index += [i for i in range(len(ranked_df)) if i not in new_index]

    # reindex ranked_df
    return ranked_df.reindex(labels=new_index, axis='index').reset_index(drop=True)

# designed more with the idea of a class object in mind
def append_schedule():
    # create empty columns
    for block in ['B1','B2','B3','B4']:
        school_pos_df[block] = ''

    # iterate through POS offerings to fill in schedule B1-B4
    for pos_key in list(pos_rosters.keys()):
        # iterate through blocks
        for block in ['B1','B2','B3','B4']:
            # iterate through Block roster
            for id in pos_rosters[pos_key][block]:
                # find and write pos under student's corresponding slot
                # row indexer
                row = school_pos_df.loc[school_pos_df.id == id].index.values
                school_pos_df.loc[school_pos_df.index[row], block] = pos_key
                
    return

def last_name(name):
    return name.split(',')[0].split()[-1]

def clean_to_export(school_pos_df, school):
    features = [
        'id',
        'name',
        'email',
        'B1',
        'B2',
        'B3',
        'B4',
        'CY Teacher',
    ]
    
    # Get homeroom/1st period teacher
    school_skyward_path = f'../YouScienceData/Skyward/Skyward_{school}.xlsx'
    school_skyward_df = pd.read_excel(school_skyward_path)

    for email in list(school_pos_df.email):
        if 'Open' in email:
            continue
        
        X = school_skyward_df.loc[school_skyward_df['Student\'s School Email'] == email]
        teacher_last, teacher_first = X['CY Teacher Last Name'].values[0], X['CY Teacher First Name'].values[0]
        school_pos_df.loc[school_pos_df.email == email, 'CY Teacher'] = str(teacher_last) + ', ' + str(teacher_first)[0]

    # alphabetize students & homeroom teacher
    school_pos_df.sort_values(['CY Teacher', 'Last Name'], inplace=True)

    # space here if we wish to transform further during iteration
    return school_pos_df[features].reset_index(drop=True)

pos_str_exceptions = set()

def export_POS_rosters(pos_keys, cleaned_df):

    for pos_key in pos_keys:
        # fixing unexpected '/' in pos_key str
        new_key = pos_key.replace('/', ', ')
            
        if new_key != pos_key:
            pos_str_exceptions.add(pos_key)
        
        # get block slices, index starting with 1 (teacher-friendly)
        b1_df = cleaned_df.loc[cleaned_df.B1 == pos_key]
        b1_df.index = np.arange(1, len(b1_df) + 1)
        b2_df = cleaned_df.loc[cleaned_df.B2 == pos_key]
        b2_df.index = np.arange(1, len(b2_df) + 1)
        b3_df = cleaned_df.loc[cleaned_df.B3 == pos_key]
        b3_df.index = np.arange(1, len(b3_df) + 1)
        b4_df = cleaned_df.loc[cleaned_df.B4 == pos_key]
        b4_df.index = np.arange(1, len(b4_df) + 1)

        # create .xlsx file for pathway
        with pd.ExcelWriter(f'../YouScienceData/Schedules/{school}/Pathway_Rosters/{new_key}.xlsx') as exwriter:
            b1_df.to_excel(exwriter, sheet_name='Block 1')
            b2_df.to_excel(exwriter, sheet_name='Block 2')
            b3_df.to_excel(exwriter, sheet_name='Block 3')
            b4_df.to_excel(exwriter, sheet_name='Block 4')

# %% [markdown]
# # Execution

# %%
log_name = input("Input file_name for log file")
with open(f'../Logs/{log_name}.txt','w') as logf:


    # dictionary for demand by school for later evaluation
    school_demand = {}
    # tracking students who were unassigned during each block but who took YS test
    missed_took_YS = {}

    for school in schools:
        # Read in school's YS matches and convert them to POS's, replace nan with 0s
        school_pos_df = get_POS_from_clusters(school)
        # initialize block rosters to contain entire school at start
        # will be reduced through process as students get assigned 
        B1_roster = school_pos_df.id.to_list()
        B2_roster = school_pos_df.id.to_list()
        B3_roster = school_pos_df.id.to_list()
        B4_roster = school_pos_df.id.to_list()
        # Want to calculate POS demand to assess any issues with allocation of rooms
        school_demand[school] = get_POS_demand(school_pos_df).most_common()
        # initialize block rosters and capacity vector for school
        pos_rosters, capacity_vector = initialize_block_rosters(school)
        # begin assignment & initialize tracker with dictionary per school
        missed_took_YS[school] = {
            'B1':[],
            'B2':[],
            'B3':[],
            'B4':[],
        }
        for block in ['B1', 'B2','B3','B4']:
            # fill forwards
            unassigned, OS_vector = fill_pos_block(block=block)
            # update tracker for those missed who took YS test
            missed_took_YS[school][block] = [x for x in unassigned if ('Missing' not in x) and ('Empty' not in x)]
            # fill backwards
            backfill_POS(block=block)
        
        append_schedule()
        # building last name feature to alphabetize cleaned_df
        for name in school_pos_df.name:
            school_pos_df.loc[school_pos_df.name == name, 'Last Name'] = last_name(name=name)
            
        cleaned_df = clean_to_export(school_pos_df, school)
        # export school-wide Pathway Schedule
        cleaned_df.to_csv(f'../YouScienceData/Schedules/{school}/{school}_all_students.csv')
        # export Pathway-specific rosters
        export_POS_rosters(pos_keys=list(pos_rosters.keys()), cleaned_df=cleaned_df)
        
logf.close()
# Out:
# Oakland Middle School registered 1 large classroom(s) available.
# Oakland Middle School needs 3 additional large rooms to meet POS demand.
# B1 Status
# BioSTEM 50
# Dietetics & Nutrition 35
# Veterinary & Animal Science/Horticulture Science 35
# Sport & Human Performance 35
# Teaching as a Profession 35
# Agricultural Engineering & Applied Technologiess 35
# Audio Visual Production 35
# Digital Arts & Design 17
# Mechantronics 24
# Cosmetology 10
# Therapeutic Services 0
# Marketing Management 6
# Banking & Finance 3
# MEP Systems 0
# Automotive Maintenance and Light Repair 0
# Business Management 1
# Residential & Commercial Construction 0
# Culinary Arts 0
# Leadership in Government 0
# 321/420
#
# B1 Status
# BioSTEM 50
# Dietetics & Nutrition 35
# Veterinary & Animal Science/Horticulture Science 35
# Sport & Human Performance 35
# Teaching as a Profession 35
# Agricultural Engineering & Applied Technologiess 35
# Audio Visual Production 35
# Digital Arts & Design 17
# Mechantronics 24
# Cosmetology 12
# Therapeutic Services 12
# Marketing Management 12
# Banking & Finance 12
# MEP Systems 12
# Automotive Maintenance and Light Repair 12
# Business Management 12
# Residential & Commercial Construction 12
# Culinary Arts 12
# Leadership in Government 11
# 420/420
#
# B2 Status
# BioSTEM 50
# Dietetics & Nutrition 35
# Veterinary & Animal Science/Horticulture Science 35
# Sport & Human Performance 26
# Teaching as a Profession 35
# Agricultural Engineering & Applied Technologiess 24
# Audio Visual Production 35
# Digital Arts & Design 26
# Mechantronics 13
# Cosmetology 10
# Therapeutic Services 5
# Marketing Management 14
# Banking & Finance 6
# MEP Systems 6
# Automotive Maintenance and Light Repair 0
# Business Management 0
# Residential & Commercial Construction 1
# Culinary Arts 0
# Leadership in Government 0
# 321/420
#
# B2 Status
# BioSTEM 50
# Dietetics & Nutrition 35
# Veterinary & Animal Science/Horticulture Science 35
# Sport & Human Performance 26
# Teaching as a Profession 35
# Agricultural Engineering & Applied Technologiess 24
# Audio Visual Production 35
# Digital Arts & Design 26
# Mechantronics 14
# Cosmetology 14
# Therapeutic Services 14
# Marketing Management 14
# Banking & Finance 14
# MEP Systems 14
# Automotive Maintenance and Light Repair 14
# Business Management 14
# Residential & Commercial Construction 14
# Culinary Arts 14
# Leadership in Government 14
# 420/420
#
# B3 Status
# BioSTEM 50
# Dietetics & Nutrition 35
# Veterinary & Animal Science/Horticulture Science 35
# Sport & Human Performance 30
# Teaching as a Profession 35
# Agricultural Engineering & Applied Technologiess 3
# Audio Visual Production 18
# Digital Arts & Design 28
# Mechantronics 11
# Cosmetology 13
# Therapeutic Services 10
# Marketing Management 10
# Banking & Finance 15
# MEP Systems 10
# Automotive Maintenance and Light Repair 6
# Business Management 6
# Residential & Commercial Construction 2
# Culinary Arts 0
# Leadership in Government 1
# 318/420
#
# B3 Status
# BioSTEM 50
# Dietetics & Nutrition 35
# Veterinary & Animal Science/Horticulture Science 35
# Sport & Human Performance 30
# Teaching as a Profession 35
# Agricultural Engineering & Applied Technologiess 16
# Audio Visual Production 18
# Digital Arts & Design 28
# Mechantronics 16
# Cosmetology 16
# Therapeutic Services 16
# Marketing Management 16
# Banking & Finance 16
# MEP Systems 16
# Automotive Maintenance and Light Repair 16
# Business Management 16
# Residential & Commercial Construction 15
# Culinary Arts 15
# Leadership in Government 15
# 420/420
#
# B4 Status
# BioSTEM 22
# Dietetics & Nutrition 35
# Veterinary & Animal Science/Horticulture Science 35
# Sport & Human Performance 35
# Teaching as a Profession 18
# Agricultural Engineering & Applied Technologiess 22
# Audio Visual Production 8
# Digital Arts & Design 11
# Mechantronics 17
# Cosmetology 17
# Therapeutic Services 10
# Marketing Management 23
# Banking & Finance 9
# MEP Systems 14
# Automotive Maintenance and Light Repair 10
# Business Management 12
# Residential & Commercial Construction 11
# Culinary Arts 1
# Leadership in Government 3
# 313/420
#
# B4 Status
# BioSTEM 34
# Dietetics & Nutrition 35
# Veterinary & Animal Science/Horticulture Science 35
# Sport & Human Performance 35
# Teaching as a Profession 19
# Agricultural Engineering & Applied Technologiess 22
# Audio Visual Production 19
# Digital Arts & Design 18
# Mechantronics 18
# Cosmetology 18
# Therapeutic Services 18
# Marketing Management 23
# Banking & Finance 18
# MEP Systems 18
# Automotive Maintenance and Light Repair 18
# Business Management 18
# Residential & Commercial Construction 18
# Culinary Arts 18
# Leadership in Government 18
# 420/420
#
# Siegel Middle School registered 2 large classroom(s) available.
# Siegel Middle School needs 6 additional large rooms to meet POS demand.
# B1 Status
# Veterinary & Animal Science 50
# Nursing Services 50
# Sport & Human Performance 35
# STEM 35
# Horticulture Sciences 35
# Digital Arts & Design 35
# Networking Systems 35
# Criminal Justice & Correction Services 35
# Pre-Law 7
# Therapeutic Services 23
# Aviation flight 20
# Marketing Management/Entrepreneurship 10
# Business Management/Accounting 0
# Leadership in Government 1
# Culinary Arts 0
# 371/430
#
# B1 Status
# Veterinary & Animal Science 50
# Nursing Services 50
# Sport & Human Performance 35
# STEM 35
# Horticulture Sciences 35
# Digital Arts & Design 35
# Networking Systems 35
# Criminal Justice & Correction Services 35
# Pre-Law 16
# Therapeutic Services 23
# Aviation flight 20
# Marketing Management/Entrepreneurship 16
# Business Management/Accounting 15
# Leadership in Government 15
# Culinary Arts 15
# 430/430
#
# B2 Status
# Veterinary & Animal Science 50
# Nursing Services 50
# Sport & Human Performance 35
# STEM 35
# Horticulture Sciences 35
# Digital Arts & Design 35
# Networking Systems 35
# Criminal Justice & Correction Services 31
# Pre-Law 12
# Therapeutic Services 19
# Aviation flight 10
# Marketing Management/Entrepreneurship 12
# Business Management/Accounting 2
# Leadership in Government 1
# Culinary Arts 0
# 362/430
#
# B2 Status
# Veterinary & Animal Science 50
# Nursing Services 50
# Sport & Human Performance 35
# STEM 35
# Horticulture Sciences 35
# Digital Arts & Design 35
# Networking Systems 35
# Criminal Justice & Correction Services 31
# Pre-Law 18
# Therapeutic Services 19
# Aviation flight 18
# Marketing Management/Entrepreneurship 18
# Business Management/Accounting 17
# Leadership in Government 17
# Culinary Arts 17
# 430/430
#
# B3 Status
# Veterinary & Animal Science 50
# Nursing Services 50
# Sport & Human Performance 35
# STEM 35
# Horticulture Sciences 35
# Digital Arts & Design 35
# Networking Systems 21
# Criminal Justice & Correction Services 14
# Pre-Law 24
# Therapeutic Services 21
# Aviation flight 10
# Marketing Management/Entrepreneurship 23
# Business Management/Accounting 6
# Leadership in Government 2
# Culinary Arts 2
# 363/430
#
# B3 Status
# Veterinary & Animal Science 50
# Nursing Services 50
# Sport & Human Performance 35
# STEM 35
# Horticulture Sciences 35
# Digital Arts & Design 35
# Networking Systems 21
# Criminal Justice & Correction Services 21
# Pre-Law 24
# Therapeutic Services 21
# Aviation flight 20
# Marketing Management/Entrepreneurship 23
# Business Management/Accounting 20
# Leadership in Government 20
# Culinary Arts 20
# 430/430
#
# B4 Status
# Veterinary & Animal Science 50
# Nursing Services 29
# Sport & Human Performance 35
# STEM 35
# Horticulture Sciences 31
# Digital Arts & Design 19
# Networking Systems 15
# Criminal Justice & Correction Services 12
# Pre-Law 22
# Therapeutic Services 16
# Aviation flight 22
# Marketing Management/Entrepreneurship 35
# Business Management/Accounting 14
# Leadership in Government 3
# Culinary Arts 8
# 346/430
#
# B4 Status
# Veterinary & Animal Science 50
# Nursing Services 38
# Sport & Human Performance 35
# STEM 35
# Horticulture Sciences 31
# Digital Arts & Design 23
# Networking Systems 23
# Criminal Justice & Correction Services 23
# Pre-Law 23
# Therapeutic Services 23
# Aviation flight 23
# Marketing Management/Entrepreneurship 35
# Business Management/Accounting 23
# Leadership in Government 23
# Culinary Arts 22
# 430/430
#
# Whitworth-Buchanan Middle School registered 2 large classroom(s) available.
# Whitworth-Buchanan Middle School needs 0 additional large rooms to meet POS demand.
# B1 Status
# Dietetics & Nutrition 50
# Sport & Human Performance 50
# Veterinary & Animal Science 35
# Agricultural Engineering & Applied Technologies 35
# Horticulture Sciences 14
# Teaching as a Profession 35
# Audio Visual Production 14
# Digital Arts & Design 0
# Criminal Justice & Correction Services 5
# Cosmetology 0
# Human & Social Sciences 0
# Therapeutic Services 0
# Automotive Maintenance and Light Repair 4
# STEM: Engineering 0
# Marketing Management 0
# Business Management 1
# Leadership in Government 0
# 243/322
#
# B1 Status
# Dietetics & Nutrition 50
# Sport & Human Performance 50
# Veterinary & Animal Science 35
# Agricultural Engineering & Applied Technologies 35
# Horticulture Sciences 14
# Teaching as a Profession 35
# Audio Visual Production 14
# Digital Arts & Design 9
# Criminal Justice & Correction Services 9
# Cosmetology 9
# Human & Social Sciences 9
# Therapeutic Services 9
# Automotive Maintenance and Light Repair 9
# STEM: Engineering 9
# Marketing Management 9
# Business Management 9
# Leadership in Government 8
# 322/322
#
# B2 Status
# Dietetics & Nutrition 50
# Sport & Human Performance 50
# Veterinary & Animal Science 3
# Agricultural Engineering & Applied Technologies 26
# Horticulture Sciences 35
# Teaching as a Profession 16
# Audio Visual Production 29
# Digital Arts & Design 14
# Criminal Justice & Correction Services 8
# Cosmetology 3
# Human & Social Sciences 0
# Therapeutic Services 0
# Automotive Maintenance and Light Repair 1
# STEM: Engineering 4
# Marketing Management 1
# Business Management 1
# Leadership in Government 1
# 242/322
#
# B2 Status
# Dietetics & Nutrition 50
# Sport & Human Performance 50
# Veterinary & Animal Science 11
# Agricultural Engineering & Applied Technologies 26
# Horticulture Sciences 35
# Teaching as a Profession 16
# Audio Visual Production 29
# Digital Arts & Design 14
# Criminal Justice & Correction Services 11
# Cosmetology 10
# Human & Social Sciences 10
# Therapeutic Services 10
# Automotive Maintenance and Light Repair 10
# STEM: Engineering 10
# Marketing Management 10
# Business Management 10
# Leadership in Government 10
# 322/322
#
# B3 Status
# Dietetics & Nutrition 35
# Sport & Human Performance 3
# Veterinary & Animal Science 35
# Agricultural Engineering & Applied Technologies 35
# Horticulture Sciences 2
# Teaching as a Profession 25
# Audio Visual Production 21
# Digital Arts & Design 26
# Criminal Justice & Correction Services 19
# Cosmetology 8
# Human & Social Sciences 3
# Therapeutic Services 0
# Automotive Maintenance and Light Repair 9
# STEM: Engineering 1
# Marketing Management 7
# Business Management 4
# Leadership in Government 1
# 234/322
#
# B3 Status
# Dietetics & Nutrition 35
# Sport & Human Performance 27
# Veterinary & Animal Science 35
# Agricultural Engineering & Applied Technologies 35
# Horticulture Sciences 11
# Teaching as a Profession 25
# Audio Visual Production 21
# Digital Arts & Design 26
# Criminal Justice & Correction Services 19
# Cosmetology 11
# Human & Social Sciences 11
# Therapeutic Services 11
# Automotive Maintenance and Light Repair 11
# STEM: Engineering 11
# Marketing Management 11
# Business Management 11
# Leadership in Government 11
# 322/322
#
# B4 Status
# Dietetics & Nutrition 0
# Sport & Human Performance 32
# Veterinary & Animal Science 35
# Agricultural Engineering & Applied Technologies 32
# Horticulture Sciences 16
# Teaching as a Profession 2
# Audio Visual Production 15
# Digital Arts & Design 12
# Criminal Justice & Correction Services 15
# Cosmetology 20
# Human & Social Sciences 8
# Therapeutic Services 3
# Automotive Maintenance and Light Repair 10
# STEM: Engineering 7
# Marketing Management 11
# Business Management 6
# Leadership in Government 1
# 225/322
#
# B4 Status
# Dietetics & Nutrition 30
# Sport & Human Performance 32
# Veterinary & Animal Science 35
# Agricultural Engineering & Applied Technologies 32
# Horticulture Sciences 16
# Teaching as a Profession 15
# Audio Visual Production 15
# Digital Arts & Design 14
# Criminal Justice & Correction Services 15
# Cosmetology 20
# Human & Social Sciences 14
# Therapeutic Services 14
# Automotive Maintenance and Light Repair 14
# STEM: Engineering 14
# Marketing Management 14
# Business Management 14
# Leadership in Government 14
# 322/322
#
# Christiana Middle School registered 0 large classroom(s) available.
# Christiana Middle School needs 2 additional large rooms to meet POS demand.
# B1 Status
# Dietetics & Nutrition 35
# Sport & Human Performance 35
# Veterinary & Animal Science 35
# Agricultural Engineering & Applied Technologies 35
# Horticulture Sciences 35
# Criminal Justice & Correction Services 35
# Teaching as a Profession 35
# Audio Visual Production 22
# Digital Arts & Design 0
# Cosmetology 6
# Human & Social Sciences 0
# Therapeutic Services 0
# Marketing Management 6
# Business Management 4
# Automotive Maintenance and Light Repair 6
# STEM: Engineering 0
# Leadership in Government 1
# 290/376
#
# B1 Status
# Dietetics & Nutrition 35
# Sport & Human Performance 35
# Veterinary & Animal Science 35
# Agricultural Engineering & Applied Technologies 35
# Horticulture Sciences 35
# Criminal Justice & Correction Services 35
# Teaching as a Profession 35
# Audio Visual Production 22
# Digital Arts & Design 13
# Cosmetology 12
# Human & Social Sciences 12
# Therapeutic Services 12
# Marketing Management 12
# Business Management 12
# Automotive Maintenance and Light Repair 12
# STEM: Engineering 12
# Leadership in Government 12
# 376/376
#
# B2 Status
# Dietetics & Nutrition 35
# Sport & Human Performance 35
# Veterinary & Animal Science 35
# Agricultural Engineering & Applied Technologies 35
# Horticulture Sciences 35
# Criminal Justice & Correction Services 11
# Teaching as a Profession 28
# Audio Visual Production 33
# Digital Arts & Design 14
# Cosmetology 10
# Human & Social Sciences 0
# Therapeutic Services 0
# Marketing Management 2
# Business Management 7
# Automotive Maintenance and Light Repair 3
# STEM: Engineering 4
# Leadership in Government 1
# 288/376
#
# B2 Status
# Dietetics & Nutrition 35
# Sport & Human Performance 35
# Veterinary & Animal Science 35
# Agricultural Engineering & Applied Technologies 35
# Horticulture Sciences 35
# Criminal Justice & Correction Services 14
# Teaching as a Profession 28
# Audio Visual Production 33
# Digital Arts & Design 14
# Cosmetology 14
# Human & Social Sciences 14
# Therapeutic Services 14
# Marketing Management 14
# Business Management 14
# Automotive Maintenance and Light Repair 14
# STEM: Engineering 14
# Leadership in Government 14
# 376/376
#
# B3 Status
# Dietetics & Nutrition 35
# Sport & Human Performance 35
# Veterinary & Animal Science 35
# Agricultural Engineering & Applied Technologies 15
# Horticulture Sciences 0
# Criminal Justice & Correction Services 34
# Teaching as a Profession 16
# Audio Visual Production 11
# Digital Arts & Design 35
# Cosmetology 10
# Human & Social Sciences 16
# Therapeutic Services 0
# Marketing Management 15
# Business Management 5
# Automotive Maintenance and Light Repair 7
# STEM: Engineering 3
# Leadership in Government 5
# 277/376
#
# B3 Status
# Dietetics & Nutrition 35
# Sport & Human Performance 35
# Veterinary & Animal Science 35
# Agricultural Engineering & Applied Technologies 17
# Horticulture Sciences 17
# Criminal Justice & Correction Services 34
# Teaching as a Profession 17
# Audio Visual Production 17
# Digital Arts & Design 35
# Cosmetology 17
# Human & Social Sciences 17
# Therapeutic Services 17
# Marketing Management 17
# Business Management 17
# Automotive Maintenance and Light Repair 17
# STEM: Engineering 16
# Leadership in Government 16
# 376/376
#
# B4 Status
# Dietetics & Nutrition 35
# Sport & Human Performance 30
# Veterinary & Animal Science 6
# Agricultural Engineering & Applied Technologies 35
# Horticulture Sciences 26
# Criminal Justice & Correction Services 15
# Teaching as a Profession 20
# Audio Visual Production 20
# Digital Arts & Design 14
# Cosmetology 15
# Human & Social Sciences 7
# Therapeutic Services 3
# Marketing Management 14
# Business Management 13
# Automotive Maintenance and Light Repair 8
# STEM: Engineering 4
# Leadership in Government 6
# 271/376
#
# B4 Status
# Dietetics & Nutrition 35
# Sport & Human Performance 30
# Veterinary & Animal Science 20
# Agricultural Engineering & Applied Technologies 35
# Horticulture Sciences 26
# Criminal Justice & Correction Services 19
# Teaching as a Profession 20
# Audio Visual Production 20
# Digital Arts & Design 19
# Cosmetology 19
# Human & Social Sciences 19
# Therapeutic Services 19
# Marketing Management 19
# Business Management 19
# Automotive Maintenance and Light Repair 19
# STEM: Engineering 19
# Leadership in Government 19
# 376/376
#
# Smyrna Middle School registered 1 large classroom(s) available.
# Smyrna Middle School needs 0 additional large rooms to meet POS demand.
# B1 Status
# Veterinary & Animal Science 50
# Health Science 35
# Horticulture Science 35
# Criminal Justice & Correction Services 29
# Audio Visual Production 35
# Digital Arts & Design 6
# Teaching as a Profession 8
# Banking & Finance 5
# Marketing Management 0
# Fashion Design 1
# STEM Technology 2
# MEP Systems 0
# Interior Design 1
# Culinary Arts 0
# Leadership in Government 0
# 207/321
#
# B1 Status
# Veterinary & Animal Science 50
# Health Science 35
# Horticulture Science 35
# Criminal Justice & Correction Services 29
# Audio Visual Production 35
# Digital Arts & Design 14
# Teaching as a Profession 14
# Banking & Finance 14
# Marketing Management 14
# Fashion Design 14
# STEM Technology 14
# MEP Systems 14
# Interior Design 13
# Culinary Arts 13
# Leadership in Government 13
# 321/321
#
# B2 Status
# Veterinary & Animal Science 50
# Health Science 35
# Horticulture Science 20
# Criminal Justice & Correction Services 23
# Audio Visual Production 24
# Digital Arts & Design 31
# Teaching as a Profession 8
# Banking & Finance 5
# Marketing Management 6
# Fashion Design 2
# STEM Technology 2
# MEP Systems 0
# Interior Design 1
# Culinary Arts 0
# Leadership in Government 0
# 207/321
#
# B2 Status
# Veterinary & Animal Science 50
# Health Science 35
# Horticulture Science 20
# Criminal Justice & Correction Services 23
# Audio Visual Production 24
# Digital Arts & Design 31
# Teaching as a Profession 16
# Banking & Finance 16
# Marketing Management 16
# Fashion Design 15
# STEM Technology 15
# MEP Systems 15
# Interior Design 15
# Culinary Arts 15
# Leadership in Government 15
# 321/321
#
# B3 Status
# Veterinary & Animal Science 19
# Health Science 30
# Horticulture Science 35
# Criminal Justice & Correction Services 21
# Audio Visual Production 19
# Digital Arts & Design 16
# Teaching as a Profession 23
# Banking & Finance 8
# Marketing Management 7
# Fashion Design 6
# STEM Technology 12
# MEP Systems 2
# Interior Design 6
# Culinary Arts 0
# Leadership in Government 0
# 204/321
#
# B3 Status
# Veterinary & Animal Science 33
# Health Science 30
# Horticulture Science 35
# Criminal Justice & Correction Services 21
# Audio Visual Production 19
# Digital Arts & Design 18
# Teaching as a Profession 23
# Banking & Finance 18
# Marketing Management 18
# Fashion Design 18
# STEM Technology 18
# MEP Systems 18
# Interior Design 18
# Culinary Arts 17
# Leadership in Government 17
# 321/321
#
# B4 Status
# Veterinary & Animal Science 0
# Health Science 19
# Horticulture Science 17
# Criminal Justice & Correction Services 25
# Audio Visual Production 14
# Digital Arts & Design 19
# Teaching as a Profession 14
# Banking & Finance 27
# Marketing Management 16
# Fashion Design 12
# STEM Technology 16
# MEP Systems 8
# Interior Design 7
# Culinary Arts 3
# Leadership in Government 1
# 198/321
#
# B4 Status
# Veterinary & Animal Science 35
# Health Science 20
# Horticulture Science 20
# Criminal Justice & Correction Services 25
# Audio Visual Production 20
# Digital Arts & Design 20
# Teaching as a Profession 20
# Banking & Finance 27
# Marketing Management 20
# Fashion Design 19
# STEM Technology 19
# MEP Systems 19
# Interior Design 19
# Culinary Arts 19
# Leadership in Government 19
# 321/321
#
# Stewarts Creek Middle School registered 2 large classroom(s) available.
# Stewarts Creek Middle School needs 2 additional large rooms to meet POS demand.
# B1 Status
# Veterinary & Animal Science 50
# Nursing Services 50
# Sport & Human Performance/Therapeutic Services 35
# Advanced STEM Applications 35
# Horticulture Sciences 35
# Cosmetology 35
# Audio Production 35
# Audio Visual Production 17
# Criminal Justice & Correction Services 16
# Networking Systems 11
# Business Management 6
# Marketing Management/Entrepreneurship 1
# Automotive Collision Repair 1
# Culinary Arts 0
# Leadership in Government 0
# 327/386
#
# B1 Status
# Veterinary & Animal Science 50
# Nursing Services 50
# Sport & Human Performance/Therapeutic Services 35
# Advanced STEM Applications 35
# Horticulture Sciences 35
# Cosmetology 35
# Audio Production 35
# Audio Visual Production 17
# Criminal Justice & Correction Services 16
# Networking Systems 13
# Business Management 13
# Marketing Management/Entrepreneurship 13
# Automotive Collision Repair 13
# Culinary Arts 13
# Leadership in Government 13
# 386/386
#
# B2 Status
# Veterinary & Animal Science 50
# Nursing Services 50
# Sport & Human Performance/Therapeutic Services 35
# Advanced STEM Applications 35
# Horticulture Sciences 31
# Cosmetology 35
# Audio Production 35
# Audio Visual Production 17
# Criminal Justice & Correction Services 16
# Networking Systems 10
# Business Management 9
# Marketing Management/Entrepreneurship 2
# Automotive Collision Repair 1
# Culinary Arts 0
# Leadership in Government 1
# 327/386
#
# B2 Status
# Veterinary & Animal Science 50
# Nursing Services 50
# Sport & Human Performance/Therapeutic Services 35
# Advanced STEM Applications 35
# Horticulture Sciences 31
# Cosmetology 35
# Audio Production 35
# Audio Visual Production 17
# Criminal Justice & Correction Services 16
# Networking Systems 14
# Business Management 14
# Marketing Management/Entrepreneurship 14
# Automotive Collision Repair 14
# Culinary Arts 13
# Leadership in Government 13
# 386/386
#
# B3 Status
# Veterinary & Animal Science 50
# Nursing Services 50
# Sport & Human Performance/Therapeutic Services 35
# Advanced STEM Applications 35
# Horticulture Sciences 7
# Cosmetology 14
# Audio Production 29
# Audio Visual Production 32
# Criminal Justice & Correction Services 21
# Networking Systems 14
# Business Management 11
# Marketing Management/Entrepreneurship 15
# Automotive Collision Repair 6
# Culinary Arts 1
# Leadership in Government 1
# 321/386
#
# B3 Status
# Veterinary & Animal Science 50
# Nursing Services 50
# Sport & Human Performance/Therapeutic Services 35
# Advanced STEM Applications 35
# Horticulture Sciences 17
# Cosmetology 17
# Audio Production 29
# Audio Visual Production 32
# Criminal Justice & Correction Services 21
# Networking Systems 17
# Business Management 17
# Marketing Management/Entrepreneurship 17
# Automotive Collision Repair 17
# Culinary Arts 16
# Leadership in Government 16
# 386/386
#
# B4 Status
# Veterinary & Animal Science 36
# Nursing Services 27
# Sport & Human Performance/Therapeutic Services 35
# Advanced STEM Applications 35
# Horticulture Sciences 28
# Cosmetology 17
# Audio Production 6
# Audio Visual Production 23
# Criminal Justice & Correction Services 8
# Networking Systems 24
# Business Management 21
# Marketing Management/Entrepreneurship 28
# Automotive Collision Repair 9
# Culinary Arts 3
# Leadership in Government 3
# 303/386
#
# B4 Status
# Veterinary & Animal Science 36
# Nursing Services 36
# Sport & Human Performance/Therapeutic Services 35
# Advanced STEM Applications 35
# Horticulture Sciences 28
# Cosmetology 20
# Audio Production 20
# Audio Visual Production 23
# Criminal Justice & Correction Services 20
# Networking Systems 24
# Business Management 21
# Marketing Management/Entrepreneurship 28
# Automotive Collision Repair 20
# Culinary Arts 20
# Leadership in Government 20
# 386/386
#
# Rockvale Middle School registered 1 large classroom(s) available.
# Rockvale Middle School needs 10 additional large rooms to meet POS demand.
# B1 Status
# Sport & Human Performance 50
# Veterinary & Animal Science 35
# Horticulture Sciences 35
# Digital Arts & Design 35
# Teaching as a Profession 35
# Criminal Justice & Correction Services 35
# Emergency Services 35
# Therapeutic Services 35
# Machining 35
# Coding 35
# Networking Systems 13
# MEP Systems 29
# Marketing Management 24
# Office Management 3
# Leadership in Government 4
# Culinary Arts 2
# 440/537
#
# B1 Status
# Sport & Human Performance 50
# Veterinary & Animal Science 35
# Horticulture Sciences 35
# Digital Arts & Design 35
# Teaching as a Profession 35
# Criminal Justice & Correction Services 35
# Emergency Services 35
# Therapeutic Services 35
# Machining 35
# Coding 35
# Networking Systems 29
# MEP Systems 29
# Marketing Management 29
# Office Management 29
# Leadership in Government 28
# Culinary Arts 28
# 537/537
#
# B2 Status
# Sport & Human Performance 50
# Veterinary & Animal Science 35
# Horticulture Sciences 35
# Digital Arts & Design 35
# Teaching as a Profession 35
# Criminal Justice & Correction Services 35
# Emergency Services 35
# Therapeutic Services 35
# Machining 35
# Coding 35
# Networking Systems 23
# MEP Systems 16
# Marketing Management 19
# Office Management 10
# Leadership in Government 2
# Culinary Arts 5
# 440/537
#
# B2 Status
# Sport & Human Performance 50
# Veterinary & Animal Science 35
# Horticulture Sciences 35
# Digital Arts & Design 35
# Teaching as a Profession 35
# Criminal Justice & Correction Services 35
# Emergency Services 35
# Therapeutic Services 35
# Machining 35
# Coding 35
# Networking Systems 29
# MEP Systems 29
# Marketing Management 29
# Office Management 29
# Leadership in Government 28
# Culinary Arts 28
# 537/537
#
# B3 Status
# Sport & Human Performance 50
# Veterinary & Animal Science 35
# Horticulture Sciences 35
# Digital Arts & Design 35
# Teaching as a Profession 35
# Criminal Justice & Correction Services 35
# Emergency Services 35
# Therapeutic Services 35
# Machining 35
# Coding 32
# Networking Systems 23
# MEP Systems 13
# Marketing Management 17
# Office Management 19
# Leadership in Government 2
# Culinary Arts 1
# 437/537
#
# B3 Status
# Sport & Human Performance 50
# Veterinary & Animal Science 35
# Horticulture Sciences 35
# Digital Arts & Design 35
# Teaching as a Profession 35
# Criminal Justice & Correction Services 35
# Emergency Services 35
# Therapeutic Services 35
# Machining 35
# Coding 32
# Networking Systems 30
# MEP Systems 29
# Marketing Management 29
# Office Management 29
# Leadership in Government 29
# Culinary Arts 29
# 537/537
#
# B4 Status
# Sport & Human Performance 50
# Veterinary & Animal Science 35
# Horticulture Sciences 35
# Digital Arts & Design 35
# Teaching as a Profession 35
# Criminal Justice & Correction Services 35
# Emergency Services 35
# Therapeutic Services 24
# Machining 13
# Coding 21
# Networking Systems 29
# MEP Systems 32
# Marketing Management 17
# Office Management 11
# Leadership in Government 7
# Culinary Arts 4
# 418/537
#
# B4 Status
# Sport & Human Performance 50
# Veterinary & Animal Science 35
# Horticulture Sciences 35
# Digital Arts & Design 35
# Teaching as a Profession 35
# Criminal Justice & Correction Services 35
# Emergency Services 35
# Therapeutic Services 31
# Machining 31
# Coding 31
# Networking Systems 31
# MEP Systems 32
# Marketing Management 31
# Office Management 30
# Leadership in Government 30
# Culinary Arts 30
# 537/537
#
# Rocky Fork Middle School registered 1 large classroom(s) available.
# Rocky Fork Middle School needs 0 additional large rooms to meet POS demand.
# B1 Status
# Veterinary & Animal Science 50
# Health Science 35
# Horticulture Science 35
# Audio Visual Production 35
# Digital Arts & Design 13
# Teaching as a Profession 19
# Fashion Design 3
# Marketing Management 9
# Criminal Justice & Correction Services 8
# STEM Technology 7
# MEP Systems 0
# Banking & Finance 0
# Interior Design 0
# Culinary Arts 0
# Leadership in Government 0
# 214/276
#
# B1 Status
# Veterinary & Animal Science 50
# Health Science 35
# Horticulture Science 35
# Audio Visual Production 35
# Digital Arts & Design 13
# Teaching as a Profession 19
# Fashion Design 10
# Marketing Management 10
# Criminal Justice & Correction Services 10
# STEM Technology 10
# MEP Systems 10
# Banking & Finance 10
# Interior Design 10
# Culinary Arts 10
# Leadership in Government 9
# 276/276
#
# B2 Status
# Veterinary & Animal Science 50
# Health Science 35
# Horticulture Science 27
# Audio Visual Production 32
# Digital Arts & Design 28
# Teaching as a Profession 8
# Fashion Design 10
# Marketing Management 3
# Criminal Justice & Correction Services 5
# STEM Technology 7
# MEP Systems 2
# Banking & Finance 3
# Interior Design 4
# Culinary Arts 0
# Leadership in Government 0
# 214/276
#
# B2 Status
# Veterinary & Animal Science 50
# Health Science 35
# Horticulture Science 27
# Audio Visual Production 32
# Digital Arts & Design 28
# Teaching as a Profession 11
# Fashion Design 11
# Marketing Management 11
# Criminal Justice & Correction Services 11
# STEM Technology 10
# MEP Systems 10
# Banking & Finance 10
# Interior Design 10
# Culinary Arts 10
# Leadership in Government 10
# 276/276
#
# B3 Status
# Veterinary & Animal Science 10
# Health Science 30
# Horticulture Science 35
# Audio Visual Production 17
# Digital Arts & Design 21
# Teaching as a Profession 31
# Fashion Design 7
# Marketing Management 15
# Criminal Justice & Correction Services 9
# STEM Technology 15
# MEP Systems 8
# Banking & Finance 7
# Interior Design 3
# Culinary Arts 0
# Leadership in Government 1
# 209/276
#
# B3 Status
# Veterinary & Animal Science 28
# Health Science 30
# Horticulture Science 35
# Audio Visual Production 17
# Digital Arts & Design 21
# Teaching as a Profession 31
# Fashion Design 12
# Marketing Management 15
# Criminal Justice & Correction Services 12
# STEM Technology 15
# MEP Systems 12
# Banking & Finance 12
# Interior Design 12
# Culinary Arts 12
# Leadership in Government 12
# 276/276
#
# B4 Status
# Veterinary & Animal Science 0
# Health Science 10
# Horticulture Science 13
# Audio Visual Production 15
# Digital Arts & Design 19
# Teaching as a Profession 15
# Fashion Design 30
# Marketing Management 22
# Criminal Justice & Correction Services 20
# STEM Technology 20
# MEP Systems 9
# Banking & Finance 9
# Interior Design 12
# Culinary Arts 3
# Leadership in Government 3
# 200/276
#
# B4 Status
# Veterinary & Animal Science 30
# Health Science 15
# Horticulture Science 15
# Audio Visual Production 15
# Digital Arts & Design 19
# Teaching as a Profession 15
# Fashion Design 30
# Marketing Management 22
# Criminal Justice & Correction Services 20
# STEM Technology 20
# MEP Systems 15
# Banking & Finance 15
# Interior Design 15
# Culinary Arts 15
# Leadership in Government 15
# 276/276
#
# Blackman Middle School registered 0 large classroom(s) available.
# Blackman Middle School needs 10 additional large rooms to meet POS demand.
# B1 Status
# Sport & Human Performance 35
# Veterinary & Animal Science 35
# Horticulture Sciences 35
# Cybersecurity 35
# Coding 35
# Audio Visual Production 35
# Digital Arts & Design 35
# Therapeutic Services 35
# Criminal Justice & Correction Services 35
# STEM Engineering 35
# Marketing Management 35
# Business Management 32
# Banking & Finance 18
# Leadership in Government 3
# Culinary Arts 1
# 439/617
#
# B1 Status
# Sport & Human Performance 42
# Veterinary & Animal Science 42
# Horticulture Sciences 41
# Cybersecurity 41
# Coding 41
# Audio Visual Production 41
# Digital Arts & Design 41
# Therapeutic Services 41
# Criminal Justice & Correction Services 41
# STEM Engineering 41
# Marketing Management 41
# Business Management 41
# Banking & Finance 41
# Leadership in Government 41
# Culinary Arts 41
# 617/617
#
# B2 Status
# Sport & Human Performance 35
# Veterinary & Animal Science 35
# Horticulture Sciences 35
# Cybersecurity 35
# Coding 35
# Audio Visual Production 35
# Digital Arts & Design 35
# Therapeutic Services 35
# Criminal Justice & Correction Services 35
# STEM Engineering 35
# Marketing Management 33
# Business Management 30
# Banking & Finance 27
# Leadership in Government 5
# Culinary Arts 2
# 447/617
#
# B2 Status
# Sport & Human Performance 42
# Veterinary & Animal Science 42
# Horticulture Sciences 41
# Cybersecurity 41
# Coding 41
# Audio Visual Production 41
# Digital Arts & Design 41
# Therapeutic Services 41
# Criminal Justice & Correction Services 41
# STEM Engineering 41
# Marketing Management 41
# Business Management 41
# Banking & Finance 41
# Leadership in Government 41
# Culinary Arts 41
# 617/617
#
# B3 Status
# Sport & Human Performance 35
# Veterinary & Animal Science 35
# Horticulture Sciences 35
# Cybersecurity 35
# Coding 35
# Audio Visual Production 35
# Digital Arts & Design 35
# Therapeutic Services 35
# Criminal Justice & Correction Services 35
# STEM Engineering 35
# Marketing Management 26
# Business Management 16
# Banking & Finance 16
# Leadership in Government 8
# Culinary Arts 2
# 418/617
#
# B3 Status
# Sport & Human Performance 42
# Veterinary & Animal Science 42
# Horticulture Sciences 41
# Cybersecurity 41
# Coding 41
# Audio Visual Production 41
# Digital Arts & Design 41
# Therapeutic Services 41
# Criminal Justice & Correction Services 41
# STEM Engineering 41
# Marketing Management 41
# Business Management 41
# Banking & Finance 41
# Leadership in Government 41
# Culinary Arts 41
# 617/617
#
# B4 Status
# Sport & Human Performance 35
# Veterinary & Animal Science 35
# Horticulture Sciences 35
# Cybersecurity 35
# Coding 35
# Audio Visual Production 35
# Digital Arts & Design 35
# Therapeutic Services 34
# Criminal Justice & Correction Services 35
# STEM Engineering 32
# Marketing Management 20
# Business Management 28
# Banking & Finance 16
# Leadership in Government 5
# Culinary Arts 7
# 422/617
#
# B4 Status
# Sport & Human Performance 42
# Veterinary & Animal Science 42
# Horticulture Sciences 41
# Cybersecurity 41
# Coding 41
# Audio Visual Production 41
# Digital Arts & Design 41
# Therapeutic Services 41
# Criminal Justice & Correction Services 41
# STEM Engineering 41
# Marketing Management 41
# Business Management 41
# Banking & Finance 41
# Leadership in Government 41
# Culinary Arts 41
# 617/617
#
# Thurman Francis Arts Academy registered 0 large classroom(s) available.
# Thurman Francis Arts Academy needs 0 additional large rooms to meet POS demand.
# B1 Status
# MEP Systems 35
# STEM Technology 28
# Teaching as a Profession 13
# Fashion Design 1
# Audio Visual Production 0
# Digital Arts & Design 0
# Horticulture Science 2
# Criminal Justice & Correction Services 0
# Veterinary & Animal Science 0
# Health Science 0
# Interior Design 1
# Banking & Finance 0
# Marketing Management 0
# Culinary Arts 0
# Leadership in Government 0
# 80/86
#
# B1 Status
# MEP Systems 35
# STEM Technology 28
# Teaching as a Profession 13
# Fashion Design 1
# Audio Visual Production 1
# Digital Arts & Design 1
# Horticulture Science 2
# Criminal Justice & Correction Services 1
# Veterinary & Animal Science 1
# Health Science 1
# Interior Design 1
# Banking & Finance 1
# Marketing Management 0
# Culinary Arts 0
# Leadership in Government 0
# 86/86
#
# B2 Status
# MEP Systems 19
# STEM Technology 35
# Teaching as a Profession 7
# Fashion Design 7
# Audio Visual Production 6
# Digital Arts & Design 0
# Horticulture Science 2
# Criminal Justice & Correction Services 3
# Veterinary & Animal Science 0
# Health Science 0
# Interior Design 0
# Banking & Finance 0
# Marketing Management 0
# Culinary Arts 0
# Leadership in Government 1
# 80/86
#
# B2 Status
# MEP Systems 19
# STEM Technology 35
# Teaching as a Profession 7
# Fashion Design 7
# Audio Visual Production 6
# Digital Arts & Design 1
# Horticulture Science 2
# Criminal Justice & Correction Services 3
# Veterinary & Animal Science 1
# Health Science 1
# Interior Design 1
# Banking & Finance 1
# Marketing Management 1
# Culinary Arts 0
# Leadership in Government 1
# 86/86
#
# B3 Status
# MEP Systems 0
# STEM Technology 0
# Teaching as a Profession 20
# Fashion Design 13
# Audio Visual Production 14
# Digital Arts & Design 6
# Horticulture Science 13
# Criminal Justice & Correction Services 8
# Veterinary & Animal Science 2
# Health Science 0
# Interior Design 3
# Banking & Finance 0
# Marketing Management 0
# Culinary Arts 0
# Leadership in Government 0
# 79/86
#
# B3 Status
# MEP Systems 1
# STEM Technology 1
# Teaching as a Profession 20
# Fashion Design 13
# Audio Visual Production 14
# Digital Arts & Design 6
# Horticulture Science 13
# Criminal Justice & Correction Services 8
# Veterinary & Animal Science 2
# Health Science 1
# Interior Design 3
# Banking & Finance 1
# Marketing Management 1
# Culinary Arts 1
# Leadership in Government 1
# 86/86
#
# B4 Status
# MEP Systems 0
# STEM Technology 0
# Teaching as a Profession 0
# Fashion Design 17
# Audio Visual Production 10
# Digital Arts & Design 14
# Horticulture Science 6
# Criminal Justice & Correction Services 8
# Veterinary & Animal Science 10
# Health Science 2
# Interior Design 4
# Banking & Finance 4
# Marketing Management 1
# Culinary Arts 0
# Leadership in Government 0
# 76/86
#
# B4 Status
# MEP Systems 2
# STEM Technology 2
# Teaching as a Profession 2
# Fashion Design 17
# Audio Visual Production 10
# Digital Arts & Design 14
# Horticulture Science 6
# Criminal Justice & Correction Services 8
# Veterinary & Animal Science 10
# Health Science 2
# Interior Design 4
# Banking & Finance 4
# Marketing Management 2
# Culinary Arts 2
# Leadership in Government 1
# 86/86
#
# Rock Springs Middle School registered 3 large classroom(s) available.
# Rock Springs Middle School needs 0 additional large rooms to meet POS demand.
# B1 Status
# Veterinary & Animal Science 50
# Nursing Services 50
# Sport & Human Performance/Therapeutic Services 45
# Advanced STEM Applications 35
# Horticulture Sciences 33
# Criminal Justice & Correction Services 18
# Marketing Management/Entrepreneurship 18
# Audio Production 3
# Audio Visual Production 0
# Networking Systems 0
# Cosmetology 0
# Educational Counseling & Social Services 0
# Automotive Collision Repair 0
# Business Management 0
# Leadership in Government 0
# Culinary Arts 0
# 252/328
#
# B1 Status
# Veterinary & Animal Science 50
# Nursing Services 50
# Sport & Human Performance/Therapeutic Services 45
# Advanced STEM Applications 35
# Horticulture Sciences 33
# Criminal Justice & Correction Services 18
# Marketing Management/Entrepreneurship 18
# Audio Production 9
# Audio Visual Production 9
# Networking Systems 9
# Cosmetology 9
# Educational Counseling & Social Services 9
# Automotive Collision Repair 9
# Business Management 9
# Leadership in Government 8
# Culinary Arts 8
# 328/328
#
# B2 Status
# Veterinary & Animal Science 50
# Nursing Services 50
# Sport & Human Performance/Therapeutic Services 1
# Advanced STEM Applications 35
# Horticulture Sciences 24
# Criminal Justice & Correction Services 26
# Marketing Management/Entrepreneurship 33
# Audio Production 24
# Audio Visual Production 1
# Networking Systems 3
# Cosmetology 2
# Educational Counseling & Social Services 0
# Automotive Collision Repair 2
# Business Management 1
# Leadership in Government 0
# Culinary Arts 0
# 252/328
#
# B2 Status
# Veterinary & Animal Science 50
# Nursing Services 50
# Sport & Human Performance/Therapeutic Services 23
# Advanced STEM Applications 35
# Horticulture Sciences 24
# Criminal Justice & Correction Services 26
# Marketing Management/Entrepreneurship 33
# Audio Production 24
# Audio Visual Production 8
# Networking Systems 8
# Cosmetology 8
# Educational Counseling & Social Services 8
# Automotive Collision Repair 8
# Business Management 8
# Leadership in Government 8
# Culinary Arts 7
# 328/328
#
# B3 Status
# Veterinary & Animal Science 45
# Nursing Services 1
# Sport & Human Performance/Therapeutic Services 50
# Advanced STEM Applications 35
# Horticulture Sciences 10
# Criminal Justice & Correction Services 16
# Marketing Management/Entrepreneurship 20
# Audio Production 21
# Audio Visual Production 25
# Networking Systems 13
# Cosmetology 4
# Educational Counseling & Social Services 0
# Automotive Collision Repair 3
# Business Management 5
# Leadership in Government 2
# Culinary Arts 0
# 250/328
#
# B3 Status
# Veterinary & Animal Science 45
# Nursing Services 26
# Sport & Human Performance/Therapeutic Services 50
# Advanced STEM Applications 35
# Horticulture Sciences 11
# Criminal Justice & Correction Services 16
# Marketing Management/Entrepreneurship 20
# Audio Production 21
# Audio Visual Production 25
# Networking Systems 13
# Cosmetology 11
# Educational Counseling & Social Services 11
# Automotive Collision Repair 11
# Business Management 11
# Leadership in Government 11
# Culinary Arts 11
# 328/328
#
# B4 Status
# Veterinary & Animal Science 0
# Nursing Services 44
# Sport & Human Performance/Therapeutic Services 49
# Advanced STEM Applications 35
# Horticulture Sciences 10
# Criminal Justice & Correction Services 3
# Marketing Management/Entrepreneurship 12
# Audio Production 8
# Audio Visual Production 21
# Networking Systems 23
# Cosmetology 13
# Educational Counseling & Social Services 4
# Automotive Collision Repair 7
# Business Management 6
# Leadership in Government 2
# Culinary Arts 5
# 242/328
#
# B4 Status
# Veterinary & Animal Science 28
# Nursing Services 44
# Sport & Human Performance/Therapeutic Services 49
# Advanced STEM Applications 35
# Horticulture Sciences 13
# Criminal Justice & Correction Services 13
# Marketing Management/Entrepreneurship 13
# Audio Production 13
# Audio Visual Production 21
# Networking Systems 23
# Cosmetology 13
# Educational Counseling & Social Services 13
# Automotive Collision Repair 13
# Business Management 13
# Leadership in Government 12
# Culinary Arts 12
# 328/328
#
# LaVergne Middle School registered 2 large classroom(s) available.
# LaVergne Middle School needs 0 additional large rooms to meet POS demand.
# B1 Status
# Veterinary & Animal Science 50
# Sport & Human Performance 50
# Horticulture Science 35
# Criminal Justice & Correction Services 35
# Marketing Management 35
# Audio Visual Production 35
# Networking Systems 28
# Virtual Reality 0
# Cosmetology 7
# Educational Counseling & Social Services 0
# Therapeutic Services 0
# Leadership in Government 1
# 276/406
#
# B1 Status
# Veterinary & Animal Science 50
# Sport & Human Performance 50
# Horticulture Science 35
# Criminal Justice & Correction Services 35
# Marketing Management 35
# Audio Visual Production 35
# Networking Systems 28
# Virtual Reality 28
# Cosmetology 28
# Educational Counseling & Social Services 28
# Therapeutic Services 27
# Leadership in Government 27
# 406/406
#
# B2 Status
# Veterinary & Animal Science 50
# Sport & Human Performance 50
# Horticulture Science 35
# Criminal Justice & Correction Services 35
# Marketing Management 35
# Audio Visual Production 26
# Networking Systems 18
# Virtual Reality 14
# Cosmetology 17
# Educational Counseling & Social Services 2
# Therapeutic Services 0
# Leadership in Government 0
# 282/406
#
# B2 Status
# Veterinary & Animal Science 50
# Sport & Human Performance 50
# Horticulture Science 35
# Criminal Justice & Correction Services 35
# Marketing Management 35
# Audio Visual Production 29
# Networking Systems 29
# Virtual Reality 29
# Cosmetology 29
# Educational Counseling & Social Services 29
# Therapeutic Services 28
# Leadership in Government 28
# 406/406
#
# B3 Status
# Veterinary & Animal Science 50
# Sport & Human Performance 18
# Horticulture Science 35
# Criminal Justice & Correction Services 35
# Marketing Management 27
# Audio Visual Production 34
# Networking Systems 22
# Virtual Reality 15
# Cosmetology 18
# Educational Counseling & Social Services 8
# Therapeutic Services 1
# Leadership in Government 2
# 265/406
#
# B3 Status
# Veterinary & Animal Science 50
# Sport & Human Performance 45
# Horticulture Science 35
# Criminal Justice & Correction Services 35
# Marketing Management 30
# Audio Visual Production 34
# Networking Systems 30
# Virtual Reality 30
# Cosmetology 30
# Educational Counseling & Social Services 29
# Therapeutic Services 29
# Leadership in Government 29
# 406/406
#
# B4 Status
# Veterinary & Animal Science 11
# Sport & Human Performance 43
# Horticulture Science 35
# Criminal Justice & Correction Services 24
# Marketing Management 16
# Audio Visual Production 7
# Networking Systems 15
# Virtual Reality 25
# Cosmetology 24
# Educational Counseling & Social Services 20
# Therapeutic Services 7
# Leadership in Government 4
# 231/406
#
# B4 Status
# Veterinary & Animal Science 46
# Sport & Human Performance 46
# Horticulture Science 35
# Criminal Justice & Correction Services 31
# Marketing Management 31
# Audio Visual Production 31
# Networking Systems 31
# Virtual Reality 31
# Cosmetology 31
# Educational Counseling & Social Services 31
# Therapeutic Services 31
# Leadership in Government 31
# 406/406

# %% [markdown]
# ## For Exporting POS rosters
#
# As is, per school, the nested dictionary object "pos_rosters[pos_key][All/block]" contains ids only. Each feature that makes sense to have on hand for a teacher leading a Pathway forum (based on my experience in the classroom) is already prepared in the cleaned_df.  <br/><br/>
# For draft 1, these features pending review:</br>
# <ul>
#     <li><i>Indexed to begin with 1 for teacher counting, alphabetized</i><br/>*Strictly alphabetized by last name without considering first name in case of shared last, etc.</li>
#     <li><strong>Block</strong></li>
#     <li><strong>Student Name</strong> <br/>(<i>feature of school_pos_df</i>)</li>
#     <li><strong>Student id</strong> <br/>(<i>key between pos_roster and school_pos_df</i>)</li>
# </ul>
#
# One block per sheet or file. It might be best to have an excel file per POS with 5 sheets, one for 'All', and four for the individual blocks. </br>
#
# <strong><i>BONUS:</i></strong> Additionally, a single .txt file per POS with the Pathway's teacher name as a title. Just thinking minimizing the lift per school.

# %%
pos_keys = list(pos_rosters.keys())
for pos_key in pos_keys:
    # getting block 1 slice and reindexing to be intuitive to teachers
    b1_df = cleaned_df.loc[cleaned_df.B1 == pos_key]
    b1_df.index = np.arange(1, len(b1_df) + 1)
    b2_df = cleaned_df.loc[cleaned_df.B2 == pos_key]
    b2_df.index = np.arange(1, len(b2_df) + 1)
    b3_df = cleaned_df.loc[cleaned_df.B3 == pos_key]
    b3_df.index = np.arange(1, len(b3_df) + 1)
    b4_df = cleaned_df.loc[cleaned_df.B4 == pos_key]
    b4_df.index = np.arange(1, len(b4_df) + 1)
    
    with pd.ExcelWriter(f'../YouScienceData/Schedules/{school}/Pathway_Rosters/{pos_key}.xlsx') as exwriter:
        b1_df.to_excel(exwriter, sheet_name='Block 1')
        b2_df.to_excel(exwriter, sheet_name='Block 2')
        b3_df.to_excel(exwriter, sheet_name='Block 3')
        b4_df.to_excel(exwriter, sheet_name='Block 4')

# %%
list(pos_rosters.keys())[2].replace('/', ', ')

# %%
pos_str_exceptions
